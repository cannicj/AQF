# %% [markdown]
# ## Compare data
#
# This Notebook checks how similar our return data (from the staddles) is to the returns given.
# Firstly, the three ways we have calculated the long returns are compared with his data.
# These are:
#
# - Option1: straddles computed with the correct weighting
# - Option2: straddles computed with the incorrect weighting (as described in the paper)
# - Option3: straddles computed with zero beta instead of zero delta
#
# Later on, the short returns are also compared with his data. There are also two different options: Correct weighting and incorrect weighting.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import numpy as np
import sqlalchemy as db
import sys
from scipy.interpolate import interp1d
import os
from datetime import datetime, timedelta
import math
import matplotlib.dates as mdates
from statsmodels.graphics.gofplots import qqplot
from statsmodels.stats.diagnostic import kstest_normal
from statsmodels.tsa.stattools import acf
from scipy.stats import norm, skew, kurtosis, shapiro, normaltest, zscore

# %%
# File paths for the CSV files
file_path_1 = 'Data/Straddles/straddle_returns_correct.csv'   # correct weighting
file_path_2 = 'Data/Straddles/straddle_returns_incorrect.csv' # incorrect weighting
file_path_3 = 'Data/Straddles/straddle_returns_beta.csv' # straddles computed with the beta
file_path_4 = 'Data/Author_Data/STRADDLE_RET.csv' # his data to compare

# Reading the CSV files into Pandas DataFrames
data_1 = pd.read_csv(file_path_1)
data_2 = pd.read_csv(file_path_2)
data_3 = pd.read_csv(file_path_3)
data_4 = pd.read_csv(file_path_4,skiprows=6)

# %%
def DATE_STR(num):
    num_str = str(num)
    date_str = num_str[-2:]+'/'+num_str[4:-2]+'/'+num_str[0:4]
    
    return date_str 

#data_2['Date'] = data_2['Date'].apply(DATE_STR)
data_4['Date'] = pd.to_datetime(data_4['Date'], format='%Y%m%d').dt.strftime('%Y-%m-%d')
data_4[data_4.columns[1:]] = data_4[data_4.columns[1:]]/100

#print('Date Range:')
#print('Start:',min(data_2.DATE).date())
#print('End:',max(data_2.DATE).date())
data_1 = data_1.rename(columns={'date': 'Date'})
data_2 = data_2.rename(columns={'date': 'Date'})
data_3 = data_3.rename(columns={'date': 'Date'})

#print(data_1)
#print(data_2)

# %%
# Merge datasets on 'Date' column
merged_data1 = pd.merge(data_1, data_4, on='Date', how='inner')
merged_data2 = pd.merge(data_2, data_4, on='Date', how='inner')
merged_data3 = pd.merge(data_3, data_4, on='Date', how='inner')

# %%
# Option1: Correct weighting
long_correct_1 = merged_data1[['Date', 'return_30', 'r_1^{straddle}']]
long_correct_2 = merged_data1[['Date', 'return_60', 'r_2^{straddle}']]
long_correct_3 = merged_data1[['Date', 'return_90', 'r_3^{straddle}']]
long_correct_6 = merged_data1[['Date', 'return_180', 'r_6^{straddle}']]
long_correct_9 = merged_data1[['Date', 'return_270', 'r_9^{straddle}']]
long_correct_12 = merged_data1[['Date', 'return_360', 'r_12^{straddle}']]
resultlist = [long_correct_1, long_correct_2, long_correct_3, long_correct_6, long_correct_9, long_correct_12]

# Calculate the number of plots to create
num_plots = len(resultlist)

# Calculate the number of rows and columns for subplots
num_cols = 3  # Number of plots to display in a row
num_rows = - (-num_plots // num_cols)  # Rounds up the division to the nearest whole number

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4 * num_rows))  # Adjust figsize as needed

# Flatten the axes if the number of subplots is less than num_rows x num_cols
axes = axes.flatten()

# Create subplots with specified titles
for i in range(num_plots):
    result = resultlist[i]
    ax = axes[i]
    maturity = result.columns[1].split('_')[1]  # Extract maturity from column name
    maturity = int(int(maturity)/30)
    ax.scatter(result.iloc[:, 1], result.iloc[:, 2])
    ax.plot(result.iloc[:, 1], result.iloc[:, 1], color='red')  # Line for correlation = 1
    ax.set_xlabel('mydata')
    ax.set_ylabel('givendata')
    ax.set_title(f'Maturity: {maturity} month')

# Hide empty subplots if the number of plots doesn't fill all the subplots
for i in range(num_plots, num_rows * num_cols):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# Calculate correlation
correlation_long_1 = long_correct_1['return_30'].corr(long_correct_1['r_1^{straddle}'])
correlation_long_2 = long_correct_2['return_60'].corr(long_correct_2['r_2^{straddle}'])
correlation_long_3 = long_correct_3['return_90'].corr(long_correct_3['r_3^{straddle}'])
correlation_long_6 = long_correct_6['return_180'].corr(long_correct_6['r_6^{straddle}'])
correlation_long_9 = long_correct_9['return_270'].corr(long_correct_9['r_9^{straddle}'])
correlation_long_12 = long_correct_12['return_360'].corr(long_correct_12['r_12^{straddle}'])
data = {
    'Maturities': [1, 2, 3, 6, 9, 12],
    'Correlations': [correlation_long_1, correlation_long_2, correlation_long_3, correlation_long_6, correlation_long_9,correlation_long_12]
}

# Create a DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    Maturities  Correlations
# 0           1      0.958436
# 1           2      0.954783
# 2           3      0.922489
# 3           6      0.878423
# 4           9      0.852109
# 5          12      0.779068

# %%
# Calculate the rolling correlation with a window of 250 observations
rolling_corr = long_correct_1['return_30'].rolling(window=250).corr(long_correct_1['r_1^{straddle}'])

# Create a new DataFrame with the dates and rolling correlation values
corr_df = pd.DataFrame({'Date': long_correct_1['Date'], 'Rolling_Correlation': rolling_corr})

# Convert the 'Date' column to datetime format
corr_df['Date'] = pd.to_datetime(corr_df['Date'])

# Plot the rolling correlation
plt.figure(figsize=(10, 5))
plt.plot(corr_df['Date'], corr_df['Rolling_Correlation'], color='blue')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of 1 month long returns')
plt.grid(True)
plt.show()

# %%
# Option2: Incorrect weighting
#Keep only 'Date' and the second column from both datasets
result_1 = merged_data2[['Date', 'return_30', 'r_1^{straddle}']]
result_2 = merged_data2[['Date', 'return_60', 'r_2^{straddle}']]
result_3 = merged_data2[['Date', 'return_90', 'r_3^{straddle}']]
result_6 = merged_data2[['Date', 'return_180', 'r_6^{straddle}']]
result_9 = merged_data2[['Date', 'return_270', 'r_9^{straddle}']]
result_12 = merged_data2[['Date', 'return_360', 'r_12^{straddle}']]
resultlist = [result_1, result_2, result_3, result_6, result_9, result_12]

# Assuming resultlist is a list of DataFrames
# Calculate the number of plots to create
num_plots = len(resultlist)

# Calculate the number of rows and columns for subplots
num_cols = 3  # Number of plots to display in a row
num_rows = - (-num_plots // num_cols)  # Rounds up the division to the nearest whole number

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4 * num_rows))  # Adjust figsize as needed

# Flatten the axes if the number of subplots is less than num_rows x num_cols
axes = axes.flatten()

for i in range(num_plots):
    result = resultlist[i]
    ax = axes[i]
    ax.scatter(result.iloc[:, 1], result.iloc[:, 2])
    ax.plot(result.iloc[:, 1], result.iloc[:, 1], color='red')  # Line for correlation = 1
    ax.set_xlabel('mydata')
    ax.set_ylabel('givendata')
    ax.set_title('Scatter plot')

# Hide empty subplots if the number of plots doesn't fill all the subplots
for i in range(num_plots, num_rows * num_cols):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# Calculate correlation
correlation1 = result_1['return_30'].corr(result_1['r_1^{straddle}'])
correlation2 = result_2['return_60'].corr(result_2['r_2^{straddle}'])
correlation3 = result_3['return_90'].corr(result_3['r_3^{straddle}'])
correlation6 = result_6['return_180'].corr(result_6['r_6^{straddle}'])
correlation9 = result_9['return_270'].corr(result_9['r_9^{straddle}'])
correlation12 = result_12['return_360'].corr(result_12['r_12^{straddle}'])
data = {
    'Maturities': [30, 60, 90, 180, 270, 360],
    'Correlations': [correlation1, correlation2, correlation3, correlation6, correlation9,correlation12]
}

# Create a DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    Maturities  Correlations
# 0          30      0.699405
# 1          60      0.916906
# 2          90      0.860781
# 3         180      0.649732
# 4         270      0.826729
# 5         360      0.761063

# %%
# Calculate the rolling correlation with a window of 250 observations
rolling_corr = result_1['return_30'].rolling(window=250).corr(result_1['r_1^{straddle}'])

# Create a new DataFrame with the dates and rolling correlation values
corr_df = pd.DataFrame({'Date': result_1['Date'], 'Rolling_Correlation': rolling_corr})

# Convert the 'Date' column to datetime format
corr_df['Date'] = pd.to_datetime(corr_df['Date'])

# Plot the rolling correlation
plt.figure(figsize=(10, 5))
plt.plot(corr_df['Date'], corr_df['Rolling_Correlation'], color='blue')

# Add labels and title
#plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of long returns')
#plt.legend()
plt.grid(True)
plt.show()

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of long returns')
plt.grid(True)
plt.show()

# %%
# Option3: calculating the returns directly via the betas
#Keep only 'Date' and the second column from both datasets
result_1 = merged_data3[['Date', 'return_30', 'r_1^{straddle}']]
result_2 = merged_data3[['Date', 'return_60', 'r_2^{straddle}']]
result_3 = merged_data3[['Date', 'return_90', 'r_3^{straddle}']]
result_6 = merged_data3[['Date', 'return_180', 'r_6^{straddle}']]
result_9 = merged_data3[['Date', 'return_270', 'r_9^{straddle}']]
result_12 = merged_data3[['Date', 'return_360', 'r_12^{straddle}']]
resultlist = [result_1, result_2, result_3, result_6, result_9, result_12]

# Calculate the number of plots to create
num_plots = len(resultlist)

# Calculate the number of rows and columns for subplots
num_cols = 3  # Number of plots to display in a row
num_rows = - (-num_plots // num_cols)  # Rounds up the division to the nearest whole number

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4 * num_rows))  # Adjust figsize as needed

# Flatten the axes if the number of subplots is less than num_rows x num_cols
axes = axes.flatten()

# Create subplots with specified titles
for i in range(num_plots):
    result = resultlist[i]
    ax = axes[i]
    maturity = result.columns[1].split('_')[1]  # Extract maturity from column name
    maturity = int(int(maturity)/30)
    ax.scatter(result.iloc[:, 1], result.iloc[:, 2])
    ax.plot(result.iloc[:, 1], result.iloc[:, 1], color='red')  # Line for correlation = 1
    ax.set_xlabel('mydata')
    ax.set_ylabel('givendata')
    ax.set_title(f'Maturity: {maturity} month')

# Hide empty subplots if the number of plots doesn't fill all the subplots
for i in range(num_plots, num_rows * num_cols):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# Calculate correlation
correlation1 = result_1['return_30'].corr(result_1['r_1^{straddle}'])
correlation2 = result_2['return_60'].corr(result_2['r_2^{straddle}'])
correlation3 = result_3['return_90'].corr(result_3['r_3^{straddle}'])
correlation6 = result_6['return_180'].corr(result_6['r_6^{straddle}'])
correlation9 = result_9['return_270'].corr(result_9['r_9^{straddle}'])
correlation12 = result_12['return_360'].corr(result_12['r_12^{straddle}'])
data = {
    'Maturities': [1, 2, 3, 6, 9, 12],
    'Correlations': [correlation1, correlation2, correlation3, correlation6, correlation9,correlation12]
}

# Create a DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    Maturities  Correlations
# 0           1      0.344657
# 1           2      0.293942
# 2           3      0.265959
# 3           6      0.205868
# 4           9      0.224752
# 5          12      0.151520

# %%
# Calculate the rolling correlation with a window of 250 observations
rolling_corr = result_1['return_30'].rolling(window=250).corr(result_1['r_1^{straddle}'])

# Create a new DataFrame with the dates and rolling correlation values
corr_df = pd.DataFrame({'Date': result_1['Date'], 'Rolling_Correlation': rolling_corr})

# Convert the 'Date' column to datetime format
corr_df['Date'] = pd.to_datetime(corr_df['Date'])

# Plot the rolling correlation
plt.figure(figsize=(10, 5))
plt.plot(corr_df['Date'], corr_df['Rolling_Correlation'], color='blue')

# Add labels and title
#plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of long returns')
#plt.legend()
plt.grid(True)
plt.show()

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of long returns')
plt.grid(True)
plt.show()

# %% [markdown]
# As one can observe, the first option with the correct weighting is closest to his data. The straddle returns computed with the beta method is completely different, the one with the correct weighting is okay, bit still worse.
# We will be using the correct weighting going forward with our analysis.

# %% [markdown]
# # Short straddle returns

# %%
# Import datasets
# File paths for the CSV files
file_path_5 = 'Data/Straddles/short_straddle_returns_correct.csv'   # correct weighting
file_path_6 = 'Data/Straddles/short_straddle_returns_incorrect.csv' # incorrect weighting

# Reading the CSV files into Pandas DataFrames
data_5 = pd.read_csv(file_path_5)
data_6 = pd.read_csv(file_path_6)

# %%
# Merge datasets on 'Date' column
merged_data4 = pd.merge(data_5, data_4, on='Date', how='inner')
merged_data5 = pd.merge(data_6, data_4, on='Date', how='inner')

# %%
#Option1: Correct weighting
short_correct_1 = merged_data4[['Date', 'r_v_30', 'r_1^{short straddle}']]
short_correct_2 = merged_data4[['Date', 'r_v_60', 'r_2^{short straddle}']]
short_correct_3 = merged_data4[['Date', 'r_v_90', 'r_3^{short straddle}']]
short_correct_6 = merged_data4[['Date', 'r_v_180', 'r_6^{short straddle}']]
short_correct_9 = merged_data4[['Date', 'r_v_270', 'r_9^{short straddle}']]
short_correct_12 = merged_data4[['Date', 'r_v_360', 'r_12^{short straddle}']]
resultlist = [short_correct_1, short_correct_2, short_correct_3, short_correct_6, short_correct_9, short_correct_12]

# Calculate the number of plots to create
num_plots = len(resultlist)

# Calculate the number of rows and columns for subplots
num_cols = 3  # Number of plots to display in a row
num_rows = - (-num_plots // num_cols)  # Rounds up the division to the nearest whole number

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4 * num_rows))  # Adjust figsize as needed

# Flatten the axes if the number of subplots is less than num_rows x num_cols
axes = axes.flatten()

# Create subplots with specified titles
for i in range(num_plots):
    result = resultlist[i]
    ax = axes[i]
    maturity = result.columns[1].split('_')[2]  # Extract maturity from column name
    maturity = int(int(maturity)/30)
    ax.scatter(result.iloc[:, 1], result.iloc[:, 2])
    ax.plot(result.iloc[:, 1], result.iloc[:, 1], color='red')  # Line for correlation = 1
    ax.set_xlabel('mydata')
    ax.set_ylabel('givendata')
    ax.set_title(f'Maturity: {maturity} month')

# Hide empty subplots if the number of plots doesn't fill all the subplots
for i in range(num_plots, num_rows * num_cols):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# Calculate correlation
correlation_short_1 = short_correct_1['r_v_30'].corr(short_correct_1['r_1^{short straddle}'])
correlation_short_2 = short_correct_2['r_v_60'].corr(short_correct_2['r_2^{short straddle}'])
correlation_short_3 = short_correct_3['r_v_90'].corr(short_correct_3['r_3^{short straddle}'])
correlation_short_6 = short_correct_6['r_v_180'].corr(short_correct_6['r_6^{short straddle}'])
correlation_short_9 = short_correct_9['r_v_270'].corr(short_correct_9['r_9^{short straddle}'])
correlation_short_12 = short_correct_12['r_v_360'].corr(short_correct_12['r_12^{short straddle}'])
data = {
    'Maturities': [1, 2, 3, 6, 9, 12],
    'Correlations': [correlation_short_1, correlation_short_2, correlation_short_3, correlation_short_6, correlation_short_9,correlation_short_12]
}

# Create a DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    Maturities  Correlations
# 0           1      0.901564
# 1           2      0.888041
# 2           3      0.822844
# 3           6      0.671091
# 4           9      0.558728
# 5          12      0.583863

# %%
# Calculate the rolling correlation with a window of 250 observations
rolling_corr = short_correct_1['r_v_30'].rolling(window=250).corr(short_correct_1['r_1^{short straddle}'])

# Create a new DataFrame with the dates and rolling correlation values
corr_df = pd.DataFrame({'Date': short_correct_1['Date'], 'Rolling_Correlation': rolling_corr})

# Convert the 'Date' column to datetime format
corr_df['Date'] = pd.to_datetime(corr_df['Date'])

# Plot the rolling correlation
plt.figure(figsize=(10, 5))
plt.plot(corr_df['Date'], corr_df['Rolling_Correlation'], color='blue')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of 1 month short returns')
plt.grid(True)
plt.show()

# %%
# Option2: Incorrect weighting
result_1 = merged_data5[['Date', 'r_v_30', 'r_1^{short straddle}']]
result_2 = merged_data5[['Date', 'r_v_60', 'r_2^{short straddle}']]
result_3 = merged_data5[['Date', 'r_v_90', 'r_3^{short straddle}']]
result_6 = merged_data5[['Date', 'r_v_180', 'r_6^{short straddle}']]
result_9 = merged_data5[['Date', 'r_v_270', 'r_9^{short straddle}']]
result_12 = merged_data5[['Date', 'r_v_360', 'r_12^{short straddle}']]
resultlist = [result_1, result_2, result_3, result_6, result_9, result_12]

# plot and get correlation
# Assuming resultlist is a list of DataFrames
# Calculate the number of plots to create
num_plots = len(resultlist)

# Calculate the number of rows and columns for subplots
num_cols = 3  # Number of plots to display in a row
num_rows = - (-num_plots // num_cols)  # Rounds up the division to the nearest whole number

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4 * num_rows))  # Adjust figsize as needed

# Flatten the axes if the number of subplots is less than num_rows x num_cols
axes = axes.flatten()

for i in range(num_plots):
    result = resultlist[i]
    ax = axes[i]
    ax.scatter(result.iloc[:, 1], result.iloc[:, 2])
    ax.plot(result.iloc[:, 1], result.iloc[:, 1], color='red')  # Line for correlation = 1
    ax.set_xlabel('mydata')
    ax.set_ylabel('givendata')
    ax.set_title('Scatter plot')

# Hide empty subplots if the number of plots doesn't fill all the subplots
for i in range(num_plots, num_rows * num_cols):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# Calculate correlation
correlation1 = result_1['r_v_30'].corr(result_1['r_1^{short straddle}'])
correlation2 = result_2['r_v_60'].corr(result_2['r_2^{short straddle}'])
correlation3 = result_3['r_v_90'].corr(result_3['r_3^{short straddle}'])
correlation6 = result_6['r_v_180'].corr(result_6['r_6^{short straddle}'])
correlation9 = result_9['r_v_270'].corr(result_9['r_9^{short straddle}'])
correlation12 = result_12['r_v_360'].corr(result_12['r_12^{short straddle}'])
data = {
    'Maturities': [30, 60, 90, 180, 270, 360],
    'Correlations': [correlation1, correlation2, correlation3, correlation6, correlation9,correlation12]
}

# Create a DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    Maturities  Correlations
# 0          30      0.856266
# 1          60      0.870863
# 2          90      0.796195
# 3         180      0.660793
# 4         270      0.545001
# 5         360      0.563972

# %%
# Calculate the rolling correlation with a window of 250 observations
rolling_corr = result_1['r_v_30'].rolling(window=250).corr(result_1['r_1^{short straddle}'])

# Create a new DataFrame with the dates and rolling correlation values
corr_df = pd.DataFrame({'Date': result_1['Date'], 'Rolling_Correlation': rolling_corr})

# Convert the 'Date' column to datetime format
corr_df['Date'] = pd.to_datetime(corr_df['Date'])

# Plot the rolling correlation
plt.figure(figsize=(10, 5))
plt.plot(corr_df['Date'], corr_df['Rolling_Correlation'], color='blue')

# Add labels and title
#plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of long returns')
#plt.legend()
plt.grid(True)
plt.show()

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of long returns')
plt.grid(True)
plt.show()

# %% [markdown]
# One can clearly see that the correct weighting is closer to his data for every maturity. The results are, especially for longer maturities, not equally as close to his data as for the long straddle returns.

# %%
# Calculate the rolling correlation for long straddle
rolling_corr_long = long_correct_1['return_30'].rolling(window=250).corr(long_correct_1['r_1^{straddle}'])

# Calculate the rolling correlation for short straddle
rolling_corr_short = short_correct_1['r_v_30'].rolling(window=250).corr(short_correct_1['r_1^{short straddle}'])

# Create a new DataFrame with the dates and rolling correlation values for both long and short
corr_df_long = pd.DataFrame({'Date': long_correct_1['Date'], 'Rolling_Correlation_Long': rolling_corr_long})
corr_df_short = pd.DataFrame({'Date': short_correct_1['Date'], 'Rolling_Correlation_Short': rolling_corr_short})

# Convert the 'Date' columns to datetime format
corr_df_long['Date'] = pd.to_datetime(corr_df_long['Date'])
corr_df_short['Date'] = pd.to_datetime(corr_df_short['Date'])

# Plot the rolling correlations on the same figure
plt.figure(figsize=(10, 5))

plt.plot(corr_df_long['Date'], corr_df_long['Rolling_Correlation_Long'], label='Long Straddle', color='blue')
plt.plot(corr_df_short['Date'], corr_df_short['Rolling_Correlation_Short'], label='Short Straddle', color='red')
plt.ylim(0.5, 1)
# Add labels and title
plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of 1 Month Returns (Corrected)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Forward data
# Check how the behavior from the staddle returns is when they are computed with the ATM definition of strike - forwardprice instead of strike - spotprice.

# %%
# File paths for the CSV files
file_path_4 = 'Data/Author_Data/STRADDLE_RET.csv' # his data to compare
file_path_5 = 'Data/Straddles/straddle_returns_forward.csv'   # returns computed with the forward price

# Reading the CSV files into Pandas DataFrames
data_4 = pd.read_csv(file_path_4,skiprows=6)
data_5 = pd.read_csv(file_path_5)
def DATE_STR(num):
    num_str = str(num)
    date_str = num_str[-2:]+'/'+num_str[4:-2]+'/'+num_str[0:4]
    
    return date_str 

#data_2['Date'] = data_2['Date'].apply(DATE_STR)
data_4['Date'] = pd.to_datetime(data_4['Date'], format='%Y%m%d').dt.strftime('%Y-%m-%d')
data_4[data_4.columns[1:]] = data_4[data_4.columns[1:]]/100

#print('Date Range:')
#print('Start:',min(data_2.DATE).date())
#print('End:',max(data_2.DATE).date())
data_5 = data_5.rename(columns={'date': 'Date'})

#print(data_1)
#print(data_2)
# Merge datasets on 'Date' column
merged_data4 = pd.merge(data_5, data_4, on='Date', how='inner')

# %%
# Option1: Correct weighting
result_1 = merged_data4[['Date', 'return_30', 'r_1^{straddle}']]
result_2 = merged_data4[['Date', 'return_60', 'r_2^{straddle}']]
result_3 = merged_data4[['Date', 'return_90', 'r_3^{straddle}']]
result_6 = merged_data4[['Date', 'return_180', 'r_6^{straddle}']]
result_9 = merged_data4[['Date', 'return_270', 'r_9^{straddle}']]
result_12 = merged_data4[['Date', 'return_360', 'r_12^{straddle}']]
resultlist = [result_1, result_2, result_3, result_6, result_9, result_12]

# Calculate the number of plots to create
num_plots = len(resultlist)

# Calculate the number of rows and columns for subplots
num_cols = 3  # Number of plots to display in a row
num_rows = - (-num_plots // num_cols)  # Rounds up the division to the nearest whole number

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4 * num_rows))  # Adjust figsize as needed

# Flatten the axes if the number of subplots is less than num_rows x num_cols
axes = axes.flatten()

for i in range(num_plots):
    result = resultlist[i]
    ax = axes[i]
    ax.scatter(result.iloc[:, 1], result.iloc[:, 2])
    ax.plot(result.iloc[:, 1], result.iloc[:, 1], color='red')  # Line for correlation = 1
    ax.set_xlabel('mydata')
    ax.set_ylabel('givendata')
    ax.set_title('Scatter plot')

# Hide empty subplots if the number of plots doesn't fill all the subplots
for i in range(num_plots, num_rows * num_cols):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# Calculate correlation
correlation1 = result_1['return_30'].corr(result_1['r_1^{straddle}'])
correlation2 = result_2['return_60'].corr(result_2['r_2^{straddle}'])
correlation3 = result_3['return_90'].corr(result_3['r_3^{straddle}'])
correlation6 = result_6['return_180'].corr(result_6['r_6^{straddle}'])
correlation9 = result_9['return_270'].corr(result_9['r_9^{straddle}'])
correlation12 = result_12['return_360'].corr(result_12['r_12^{straddle}'])
data = {
    'Maturities': [1, 2, 3, 6, 9, 12],
    'Correlations': [correlation1, correlation2, correlation3, correlation6, correlation9,correlation12]
}

# Create a DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    Maturities  Correlations
# 0           1      0.960781
# 1           2      0.957694
# 2           3      0.923483
# 3           6      0.900959
# 4           9      0.865473
# 5          12      0.788833

# %%
# Calculate the rolling correlation with a window of 250 observations
rolling_corr = result_1['return_30'].rolling(window=250).corr(result_1['r_1^{straddle}'])

# Create a new DataFrame with the dates and rolling correlation values
corr_df = pd.DataFrame({'Date': result_1['Date'], 'Rolling_Correlation': rolling_corr})

# Convert the 'Date' column to datetime format
corr_df['Date'] = pd.to_datetime(corr_df['Date'])

# Plot the rolling correlation
plt.figure(figsize=(10, 5))
plt.plot(corr_df['Date'], corr_df['Rolling_Correlation'], color='blue')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Correlation')
plt.title('Rolling Correlation of long returns (computed with forward prices)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Compare our returns with his returns
# Code was originally written in predictive_performance notebook, after having seen differences in the performance of the strategies.
# The analysis is focused on the 30-day (1 month daily returns), as they are used in the conditional investment strategy.

# %%
# Import all our data we want to work within this section
#File paths for the CSV files
file_path = 'Data/Straddles/straddle_returns_correct.csv'
file_path1 = 'Data/Straddles/short_straddle_returns_correct.csv'
file_path2 = 'Data/Author_Data/STRADDLE_RET.csv'

# Reading the CSV files into Pandas DataFrames
returns_long = pd.read_csv(file_path)
returns_long = returns_long.rename(columns={'date': 'Date'})
returns_long['Date'] = pd.to_datetime(returns_long['Date'])
returns_short = pd.read_csv(file_path1)
returns_short = returns_short.rename(columns={'date': 'Date'})
returns_short['Date'] = pd.to_datetime(returns_short['Date'])

# his given returns include long and short returns (name differ accordingly)
STRADDLE_RET_given = pd.read_csv(file_path2, skiprows=6)
STRADDLE_RET_given['Date'] = pd.to_datetime(STRADDLE_RET_given['Date'], format='%Y%m%d').dt.strftime('%Y-%m-%d')
STRADDLE_RET_given['Date'] = pd.to_datetime(STRADDLE_RET_given['Date'])
STRADDLE_RET_given[STRADDLE_RET_given.columns[1:]] = STRADDLE_RET_given[STRADDLE_RET_given.columns[1:]]/100

# %%
# Merge returns_long and short_returns on the "Date" column
merged_df = pd.merge(returns_long, returns_short, on='Date', how='inner')

# Merge the resulting dataframe with STRADDLE_RET_given on the "Date" column
straddle_returns = pd.merge(merged_df, STRADDLE_RET_given, on='Date', how='inner')
straddle_returns = straddle_returns[['Date', 'return_30', 'r_v_30', 'r_1^{straddle}', 'r_1^{short straddle}']]
straddle_returns = straddle_returns.rename(columns={'return_30': 'Custom: Returns long'})
straddle_returns = straddle_returns.rename(columns={'r_v_30': 'Custom: Returns short'})
straddle_returns = straddle_returns.rename(columns={'r_1^{straddle}': 'Author: Returns long'})
straddle_returns = straddle_returns.rename(columns={'r_1^{short straddle}': 'Author: Returns short'})

straddle_returns
# Out:
#            Date  Custom: Returns long  Custom: Returns short  \
# 0    1996-01-05             -0.047362               0.002855
# 1    1996-01-08             -0.050125               0.003020
# 2    1996-01-09              0.352578              -0.020640
# 3    1996-01-10              0.120899              -0.008543
# 4    1996-01-11             -0.096908               0.007298
# ...         ...                   ...                    ...
# 5903 2019-06-24             -0.053542               0.003957
# 5904 2019-06-25              0.020247              -0.001429
# 5905 2019-06-26             -0.035831               0.002890
# 5906 2019-06-27             -0.016247               0.001278
# 5907 2019-06-28             -0.003772               0.000288
#
#       Author: Returns long  Author: Returns short
# 0                 -0.04067                0.00500
# 1                 -0.01795                0.00224
# 2                  0.34233               -0.04098
# ...

# %%
max_value = straddle_returns['Custom: Returns long'].max()
best_row = straddle_returns.loc[straddle_returns['Custom: Returns long'] == max_value]
print('Biggest long return our data:')
print(best_row)

max_value = straddle_returns['Custom: Returns short'].max()
best_row = straddle_returns.loc[straddle_returns['Custom: Returns short'] == max_value]
print('Biggest short return our data:')
print(best_row)

max_value = straddle_returns['Author: Returns long'].max()
best_row = straddle_returns.loc[straddle_returns['Author: Returns long'] == max_value]
print('Biggest long return author data:')
print(best_row)

max_value = straddle_returns['Author: Returns short'].max()
best_row = straddle_returns.loc[straddle_returns['Author: Returns short'] == max_value]
print('Biggest short return his data:')
print(best_row)
# Out:
# Biggest long return our data:
#            Date  Custom: Returns long  Custom: Returns short  \
# 2801 2007-02-27              1.114533              -0.060919
#
#       Author: Returns long  Author: Returns short
# 2801               0.86382               -0.10319
# Biggest short return our data:
#            Date  Custom: Returns long  Custom: Returns short  \
# 2917 2007-08-13             -0.109621               0.101376
#
#       Author: Returns long  Author: Returns short
# 2917              -0.13973                0.03858
# Biggest long return author data:
#            Date  Custom: Returns long  Custom: Returns short  \
# 2801 2007-02-27              1.114533              -0.060919
#
#       Author: Returns long  Author: Returns short
# 2801               0.86382               -0.10319
# Biggest short return his data:
#            Date  Custom: Returns long  Custom: Returns short  \
# 3217 2008-10-20             -0.139894               0.075198
#
# ...

# %% [markdown]
# Max values are on the same date! Same for min values?

# %%
min_value = straddle_returns['Custom: Returns long'].min()
worst_row = straddle_returns.loc[straddle_returns['Custom: Returns long'] == min_value]
print('Worst long return our data:')
print(worst_row)

min_value = straddle_returns['Custom: Returns short'].min()
worst_row = straddle_returns.loc[straddle_returns['Custom: Returns short'] == min_value]
print('Worst short return our data:')
print(worst_row)

min_value = straddle_returns['Author: Returns long'].min()
worst_row = straddle_returns.loc[straddle_returns['Author: Returns long'] == min_value]
print('Worst long return author data:')
print(worst_row)

min_value = straddle_returns['Author: Returns short'].min()
worst_row = straddle_returns.loc[straddle_returns['Author: Returns short'] == min_value]
print('Worst short return his data:')
print(worst_row)
# Out:
# Worst long return our data:
#            Date  Custom: Returns long  Custom: Returns short  \
# 5558 2018-02-07             -0.240796               0.029401
#
#       Author: Returns long  Author: Returns short
# 5558              -0.23153                0.05756
# Worst short return our data:
#            Date  Custom: Returns long  Custom: Returns short  \
# 3202 2008-09-29              0.527548              -0.148267
#
#       Author: Returns long  Author: Returns short
# 3202               0.36726               -0.13627
# Worst long return author data:
#            Date  Custom: Returns long  Custom: Returns short  \
# 5558 2018-02-07             -0.240796               0.029401
#
#       Author: Returns long  Author: Returns short
# 5558              -0.23153                0.05756
# Worst short return his data:
#           Date  Custom: Returns long  Custom: Returns short  \
# 458 1997-10-27              0.874486               -0.10426
#
# ...

# %% [markdown]
# Long returns match, short returns do not.

# %%
# List of columns for which you want to create individual plots
columns_to_plot = ['Custom: Returns long', 'Custom: Returns short', 'Author: Returns long', 'Author: Returns short']

# Set up subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
fig.suptitle('Individual Distributions')

# Plot individual distributions
for i, col in enumerate(columns_to_plot):
    sns.histplot(straddle_returns[col], kde=True, ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title(col)

# Plot to compare distributions
plt.figure(figsize=(10, 6))
sns.kdeplot(data=straddle_returns[columns_to_plot], fill=True)
plt.title('Comparison of Distributions')

plt.show()

# %%
straddle_returns
# Out:
#            Date  Custom: Returns long  Custom: Returns short  \
# 0    1996-01-05             -0.047362               0.002855
# 1    1996-01-08             -0.050125               0.003020
# 2    1996-01-09              0.352578              -0.020640
# 3    1996-01-10              0.120899              -0.008543
# 4    1996-01-11             -0.096908               0.007298
# ...         ...                   ...                    ...
# 5903 2019-06-24             -0.053542               0.003957
# 5904 2019-06-25              0.020247              -0.001429
# 5905 2019-06-26             -0.035831               0.002890
# 5906 2019-06-27             -0.016247               0.001278
# 5907 2019-06-28             -0.003772               0.000288
#
#       Author: Returns long  Author: Returns short
# 0                 -0.04067                0.00500
# 1                 -0.01795                0.00224
# 2                  0.34233               -0.04098
# ...

# %%
# List of columns to analyze
columns_to_analyze = ['Custom: Returns long', 'Custom: Returns short', 'Author: Returns long', 'Author: Returns short']

# Descriptive Statistics
summary_stats = straddle_returns[columns_to_analyze].describe()

# Data Visualization
plt.figure(figsize=(12, 8))
for i, col in enumerate(columns_to_analyze, 1):
    plt.subplot(2, 2, i)
    sns.histplot(straddle_returns[col], kde=True)
    plt.title(f'Histogram for {col}')
plt.tight_layout()

# Quantile-Quantile (Q-Q) Plots
plt.figure(figsize=(12, 8))
for i, col in enumerate(columns_to_analyze, 1):
    plt.subplot(2, 2, i)
    qqplot(straddle_returns[col], line='s', ax=plt.gca())
    plt.title(f'Q-Q Plot for {col}')
plt.tight_layout()

# Time Series Plots
# Assuming there's a time-related column, replace 'Date' with the actual time-related column
time_column = 'Date'
if time_column in straddle_returns.columns:
    plt.figure(figsize=(12, 8))
    for i, col in enumerate(columns_to_analyze, 1):
        plt.subplot(2, 2, i)
        sns.lineplot(x=straddle_returns[time_column], y=straddle_returns[col])
        plt.title(f'Time Series Plot for {col}')
    plt.tight_layout()

# Outlier Detection
z_scores = pd.DataFrame({col: zscore(straddle_returns[col]) for col in columns_to_analyze})
outliers = (np.abs(z_scores) > 3).any(axis=1)

# Higher Moments (Skewness and Kurtosis)
skewness = straddle_returns[columns_to_analyze].apply(skew)
kurt = straddle_returns[columns_to_analyze].apply(kurtosis)

# Comparison of Empirical and Theoretical Quantiles
plt.figure(figsize=(12, 8))
for i, col in enumerate(columns_to_analyze, 1):
    plt.subplot(2, 2, i)
    sns.histplot(straddle_returns[col], kde=True, stat='density')
    _, p_value_ks = kstest_normal(straddle_returns[col])
    plt.title(f'KS Test p-value: {p_value_ks:.4f} for {col}')
plt.tight_layout()

# Segmentation Analysis (Example: assuming 'our_condition' is a categorical column for segmentation)
segment_column = 'our_condition'
if segment_column in straddle_returns.columns:
    for segment_value in straddle_returns[segment_column].unique():
        segment_data = straddle_returns[straddle_returns[segment_column] == segment_value]
        # Perform analysis on the segmented data
        # You can reuse the code snippets above with this segmented data

# Display Descriptive Statistics
print("Descriptive Statistics:")
print(summary_stats)

# Display Skewness and Kurtosis
print("\nSkewness:")
print(skewness)
print("\nKurtosis:")
print(kurt)

# Display Outliers
outliers_df = straddle_returns[outliers].copy()
outliers_df['outlier_column'] = outliers_df[columns_to_analyze].apply(lambda x: x.idxmax(), axis=1)
print("\nOutliers:")
print(outliers_df)

# Display Comparison of Empirical and Theoretical Quantiles
for col in columns_to_analyze:
    _, p_value_ks = kstest_normal(straddle_returns[col])
    print(f"\nKS Test p-value for {col}: {p_value_ks:.4f}")

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\_lilliefors.py:272: FutureWarning: The default pvalmethod will change from "approx" to "table" after 0.11. The "table" method uses values from a very large simulation and is more accurate.  Explicitly set this parameter to "approx" or "table" to silence this warning
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\_lilliefors.py:272: FutureWarning: The default pvalmethod will change from "approx" to "table" after 0.11. The "table" method uses values from a very large simulation and is more accurate.  Explicitly set this parameter to "approx" or "table" to silence this warning
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Data Visualization with Improved Colors
plt.figure(figsize=(12, 8))

# Overlay Histogram for return_30 and r_1^{straddle}
plt.subplot(2, 2, 1)
sns.histplot(straddle_returns['Custom: Returns long'], kde=True, label='Custom: Returns long', color='darkblue', alpha=0.7)
sns.histplot(straddle_returns['Author: Returns long'], kde=True, label='Author: Returns long', color='lightgrey', alpha=0.7)
plt.title('Histogram Overlay for long returns')
plt.legend()

# Overlay Histogram for r_v_30 and r_1^{short straddle}
plt.subplot(2, 2, 2)
sns.histplot(straddle_returns['Custom: Returns short'], kde=True, label='Custom: Returns short', color='darkblue', alpha=0.7)
sns.histplot(straddle_returns['Author: Returns short'], kde=True, label='Author: Returns short', color='lightgrey', alpha=0.7)
plt.title('Histogram Overlay for short returns')
plt.legend()

# Q-Q Plots with Different Colors
plt.subplot(2, 2, 3)
qqplot(straddle_returns['Custom: Returns long'], line='s', ax=plt.gca(), label='Custom: Returns long', color='darkblue')
qqplot(straddle_returns['Author: Returns long'], line='s', ax=plt.gca(), label='Author: Returns long', color='lightgrey')
plt.title('Q-Q Plot Overlay for long returns')
plt.legend()

plt.subplot(2, 2, 4)
qqplot(straddle_returns['Custom: Returns short'], line='s', ax=plt.gca(), label='Custom: Returns short', color='darkblue')
qqplot(straddle_returns['Author: Returns short'], line='s', ax=plt.gca(), label='Author: Returns short', color='lightgrey')
plt.title('Q-Q Plot Overlay for short returns')
plt.legend()

plt.tight_layout()
plt.show()
